# %% [markdown]
# ***Importing the Tools and Python Package which can be used for this assignment***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import linregress

# %% [markdown]
# ***Dataset: "World Happiness Report.csv"***

# %% [markdown]
# **Tasks - To - Do:**

# %% [markdown]
# **Problem - 1:**
#
# **Getting Started with Data Exploration - Some Warm up
# Exercises:**

# %% [markdown]
# 1. Data Exploration and Understanding:

# %% [markdown]
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
# 1: Load the dataset and display the first 10 rows.
df = pd.read_csv("/content/drive/MyDrive/5CS037 - Concepts and Technologies of AI/Assignment-1/WHR-2024-5CS037.csv")
# df.info()
print("First 10 rows of the dataset:")
df.head(10)
# Out:
# First 10 rows of the dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
# 2: Identify the number of rows and columns in the dataset.
rows, columns = df.shape
print("Number of rows and columns in the dataset:")
print("Rows:",rows,"Columns:",columns)
# Out:
# Number of rows and columns in the dataset:
# Rows: 143 Columns: 9

# %%
# 3: List all the columns and their data types.
print("The datatypes of columnn:")
print(df.dtypes)
# Out:
# The datatypes of columnn:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
# 1: Calculate the mean, median, and standard deviation for the Score column.
mean_score = df['score'].mean()
median_score = df['score'].median()
standard_deviation_score = df['score'].std()

print("Mean, Median, and Standard Deviation for the Score column: \n")
print("Mean:",mean_score)
print("Median:",median_score)
print("Standard Deviation:",standard_deviation_score)
# Out:
# Mean, Median, and Standard Deviation for the Score column:
#
# Mean: 5.52758041958042
# Median: 5.785
# Standard Deviation: 1.1707165099442995

# %%
# 2: Identify the country with the highest and lowest happiness scores

highest_happiness_score = df.loc[df['score'].idxmax()]['Country name']
lowest_happiness_score = df.loc[df['score'].idxmin()]['Country name']

print("Country with highest happiness score:", highest_happiness_score)
print("Country with lowest happiness score:", lowest_happiness_score)
# Out:
# Country with highest happiness score: Finland
# Country with lowest happiness score: Afghanistan

# %% [markdown]
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# 1: Check if there are any missing values in the dataset. If so, display the total count for each column.
missing_values = df.isnull().sum()

print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
# 1: Filter the dataset to show only the countries with a Score greater than 7.5.
filtered_dataset = df[df['score'] > 7.5]
print("Countries with a Score greater than 7.5: \n")
filtered_dataset
# Out:
# Countries with a Score greater than 7.5:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
# 2: For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the top 10 rows.
filtered_dataset_sorted = filtered_dataset.sort_values(by='Log GDP per capita', ascending=False).head(10)
print("Top Countries with highest GDP: \n")
filtered_dataset_sorted
# Out:
# Top Countries with highest GDP:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# • Adding New Columns:
#
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
#
# Medium − (4 ≤ Score ≤ 6)
#
# High − (Score > 6)

# %%
# 1: Create a new column called Happiness Category that categorizes countries into three categories based on their Score.
def happiness_category(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'

df['Happiness Category'] = df['score'].apply(happiness_category)
print("'Happiness Category' column added to the dataset: \n")
df[['Country name', 'score', 'Happiness Category']]
# Out:
# 'Happiness Category' column added to the dataset:
#          Country name  score Happiness Category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [143 rows x 3 columns]

# %% [markdown]
# 2. Data Visualizations:

# %% [markdown]
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
top_10_happiest = df.sort_values(by='score', ascending=False).head(10)
# top_10_happiest
plt.figure(figsize=(11, 6))
plt.bar(top_10_happiest['Country name'], top_10_happiest['score'],edgecolor='black')
plt.xlabel('Country', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.title('Top 10 Happiest Countries(On the basis of Score)', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
top_10_unhappiest = df.sort_values(by='score', ascending=True).head(10)
# top_10_unhappiest
plt.figure(figsize=(13, 5))
plt.plot(top_10_unhappiest['Country name'], top_10_unhappiest['score'], marker='o')
plt.xlabel('Country', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.title('Top 10 Unhappiest Countries (On the basis of Score)', fontsize=14)
plt.grid(True, linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['score'], bins=20, kde=True, color='green')
plt.title('Distribution of Happiness Score', fontsize=14)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Log GDP per capita'], df['score'], color='blue',alpha=0.6)
plt.xlabel('Log GDP per Capita', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.title('Relationship Between GDP per Capita and Happiness Score', fontsize=14)
plt.grid(True, linestyle='-', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Problem - 2:**
#
# **Some Advance Data Exploration Task:**

# %% [markdown]
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
#
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
#
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
# 1: Define the countries in South Asia with a list
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan",
    "India", "Maldives", "Nepal",
    "Pakistan", "Sri Lanka"
]
# south_asian_countries

# %%
# 2: Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
south_asia_data = df[df['Country name'].isin(south_asian_countries)]
# south_asia_data

# %%
# 3: Save the filtered dataframe as separate CSV files for future use.
south_asia_data.to_csv('south_asia_happiness.csv', index=False)

print("Dataset saved: 'south_asia_happiness_report.csv'")
# Out:
# Dataset saved: 'south_asia_happiness_report.csv'

# %% [markdown]
# Task - 2 - Composite Score Ranking:
#
# Tasks:
#
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#                  Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support  + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
# 1: Using the SouthAsia DataFrame, create a new column called Composite Score
south_asia_data=pd.read_csv('/content/south_asia_happiness.csv')
south_asia_data['Composite Score'] = (
    0.40 * south_asia_data['Log GDP per capita'] +
    0.30 * south_asia_data['Social support'] +
    0.30 * south_asia_data['Healthy life expectancy']
)
south_asia_data[['Country name','Composite Score']]
# Out:
#   Country name  Composite Score
# 0        Nepal           0.8159
# 1     Pakistan           0.7039
# 2        India           0.7874
# 3    Sri Lanka           1.0739
# 4   Bangladesh           0.6774
# 5  Afghanistan           0.3238

# %%
# 2: Rank the South Asian countries based on the Composite Score in descending order.
south_asia_ranked = south_asia_data.sort_values(by='Composite Score', ascending=False)
south_asia_ranked[['Country name','Composite Score']]
# Out:
#   Country name  Composite Score
# 3    Sri Lanka           1.0739
# 0        Nepal           0.8159
# 2        India           0.7874
# 1     Pakistan           0.7039
# 4   Bangladesh           0.6774
# 5  Afghanistan           0.3238

# %%
# 3: Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
top_5_countries = south_asia_ranked.head(5)
plt.figure(figsize=(8, 5))
sns.barplot( x='Composite Score', y='Country name',hue='Country name',data=top_5_countries)
plt.title('Top 5 South Asian Countries by Composite Score', fontsize=14)
plt.xlabel('Composite Score', fontsize=12)
plt.ylabel('Country Name', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# 4: Discuss whether the rankings based on the Composite Score align with the original Score -
#    support your discussion with some visualization plot.
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Composite Score', y='score', data=south_asia_ranked, hue='Country name', s=100)
plt.title('Comparison of Composite Score and Original Happiness Score', fontsize=16)
plt.xlabel('Composite Score', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Task - 3 - Outlier Detection:
#
# Tasks:
#
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
# 1 and 2: Identify outlier countries in South Asia based on their Score and GDP per Capita.
#          Define outliers using the 1.5 × IQR rule.
data=pd.read_csv('/content/south_asia_happiness.csv')
def find_outliers(column):
    q1 = np.percentile(data[column], 25)
    q3 = np.percentile(data[column], 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return lower_bound, upper_bound
outlier_score = find_outliers('score')
outlier_gdp = find_outliers('Log GDP per capita')

data['Outlier'] = (
    (data['score'] < outlier_score[0]) | (data['score'] > outlier_score[1]) |
    (data['Log GDP per capita'] < outlier_gdp[0]) | (data['Log GDP per capita'] > outlier_gdp[1])
)
outliers = data[data['Outlier']]
print("Outlier Countries: ")
print(outliers[['Country name','score','Log GDP per capita','Outlier']])
print("\n")
# Out:
# Outlier Countries:
#   Country name  score  Log GDP per capita  Outlier
# 5  Afghanistan  1.721               0.628     True

# %%
# 3: Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis,
#    highlighting outliers in a different color
plt.figure(figsize=(10, 6))
plt.scatter(data['Log GDP per capita'], data['score'], label='Non-Outliers', color='blue', alpha=0.7)
plt.scatter(outliers['Log GDP per capita'], outliers['score'], label='Outliers', color='red', edgecolor='black',s=100)
plt.xlabel('Log GDP per Capita', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.title(' GDP vs Happiness Score of South Asian Countries', fontsize=14)
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:
#
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
# 1: Choose two metrics (e.g., Freedom to Make Life Choices and Generosity)
#    and calculate their correlation {pearson correlation} with the Score for South Asian countries.
data = pd.read_csv('/content/south_asia_happiness.csv')

metrics = ['Freedom to make life choices', 'Generosity']
correlations = {}

for metric in metrics:
    corr = data['score'].corr(data[metric])
    correlations[metric] = corr

print("Pearson Correlations with Happiness Score:")
for metric, corr in correlations.items():
    print(f"{metric}: {corr:.2f}")
# Out:
# Pearson Correlations with Happiness Score:
# Freedom to make life choices: 0.80
# Generosity: 0.87

# %%
# 2: Create scatter plots with trendlines for these metrics against the Score.
def scatter_with_trendline(x, y, xlabel, ylabel, title):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    trendline = slope * x + intercept


    plt.figure(figsize=(10, 5))
    plt.scatter(x, y, label='Data Points', color='blue', alpha=0.7)
    plt.plot(x, trendline, label=f'Trendline (R² = {r_value**2:.2f})', color='red')
    plt.xlabel(xlabel, fontsize=12)
    plt.ylabel(ylabel, fontsize=12)
    plt.title(title, fontsize=14)
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()
for metric in metrics:
    scatter_with_trendline(x=data[metric],y=data['score'],xlabel=metric,ylabel='Happiness Score',title=f'Happiness Score vs {metric}')

# %%
# 3: Identify and discuss the strongest and weakest relationships
#    between these metrics and the Score for South Asian countries.
strongest_metric = max(correlations, key=correlations.get)
weakest_metric = min(correlations, key=correlations.get)

print("\nAnalysis:")
print(f"The strongest relationship is with '{strongest_metric}' (Correlation: {correlations[strongest_metric]:.2f}).")
print(f"The weakest relationship is with '{weakest_metric}' (Correlation: {correlations[weakest_metric]:.2f}).")
# Out:
# Analysis:
# The strongest relationship is with 'Generosity' (Correlation: 0.87).
# The weakest relationship is with 'Freedom to make life choices' (Correlation: 0.80).

# %% [markdown]
# Task - 5 - Gap Analysis:
#
# Tasks:
#
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# 1: Add a new column, GDP-Score Gap,
#    which is the difference between GDP per Capita and the Score for each South Asian country.
south_asia_data = pd.read_csv('/content/south_asia_happiness.csv')
south_asia_data['GDP-Score Gap'] = south_asia_data['Log GDP per capita'] - south_asia_data['score']
south_asia_data[['Country name','Log GDP per capita','score','GDP-Score Gap']]
# Out:
#   Country name  Log GDP per capita  score  GDP-Score Gap
# 0        Nepal               0.965  5.158         -4.193
# 1     Pakistan               1.069  4.657         -3.588
# 2        India               1.166  4.054         -2.888
# 3    Sri Lanka               1.361  3.898         -2.537
# 4   Bangladesh               1.122  3.886         -2.764
# 5  Afghanistan               0.628  1.721         -1.093

# %%
# 2: Rank the South Asian countries by this gap in both ascending and descending order.
ascending_gap = south_asia_data.sort_values('GDP-Score Gap', ascending=True)
descending_gap = south_asia_data.sort_values('GDP-Score Gap', ascending=False)
print("South Asian Cuntries ranked by GDP-Score Gap in ascending oreder:\n")
print(ascending_gap[['Country name', 'GDP-Score Gap']],"\n")
print("South Asian Cuntries ranked by GDP-Score Gap in descending oreder:\n")
print(descending_gap[['Country name', 'GDP-Score Gap']])
# Out:
# South Asian Cuntries ranked by GDP-Score Gap in ascending oreder:
#
#   Country name  GDP-Score Gap
# 0        Nepal         -4.193
# 1     Pakistan         -3.588
# 2        India         -2.888
# 4   Bangladesh         -2.764
# 3    Sri Lanka         -2.537
# 5  Afghanistan         -1.093
#
# South Asian Cuntries ranked by GDP-Score Gap in descending oreder:
#
#   Country name  GDP-Score Gap
# 5  Afghanistan         -1.093
# 3    Sri Lanka         -2.537
# 4   Bangladesh         -2.764
# 2        India         -2.888
# 1     Pakistan         -3.588
# 0        Nepal         -4.193

# %%
# 3: Highlight the top 3 countries with the largest positive and negative gaps using a bar chart

positive_gaps = descending_gap.head(3)
print("Largest Positive gaps: \n")
print(positive_gaps[['Country name']])
negative_gaps = ascending_gap.head(3)
print("\n Largest negative gaps: \n")
print(negative_gaps[['Country name']])

top_countries = pd.concat([positive_gaps, negative_gaps])

plt.figure(figsize=(10, 5))
colors = ['green'] * 3 + ['red'] * 3
sns.barplot(data=top_countries, x='Country name',y='GDP-Score Gap',palette=colors,hue='Country name')
plt.title('Top 3 Largest Positive and Negative GDP-Score Gaps')
plt.xlabel('Country',fontsize=12)
plt.ylabel('GDP-Score Gap',fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Largest Positive gaps:
#
#   Country name
# 5  Afghanistan
# 3    Sri Lanka
# 4   Bangladesh
#
#  Largest negative gaps:
#
#   Country name
# 0        Nepal
# 1     Pakistan
# 2        India

# %% [markdown]
# **Problem - 3 - Comparative Analysis:**

# %% [markdown]
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
#
# Tasks:
#
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
#
#      middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# %%
# 1: Create a dataframe from middle eastern countries.
middle_east_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon",
    "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
    "United Arab Emirates", "Yemen"
]

middle_east_data = df[df['Country name'].isin(middle_east_countries)]
middle_east_data
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# 1. Descriptive Statistics:
#
#    • Calculate the mean, Standard deviation of the score for
#       both South Asia and Middle East.
#
#    • Which region has higher happiness Scores on average?

# %%
# Calculate the mean, Standard deviation of the score for
# both South Asia and Middle East.

south_asia_mean = south_asia_data['score'].mean()
south_asia_std = south_asia_data['score'].std()

middle_east_mean = middle_east_data['score'].mean()
middle_east_std = middle_east_data['score'].std()

print("Mean and Standard Deviation of Score for South Asia:")
print(f"Mean: {south_asia_mean:.2f}, Standard Deviation: {south_asia_std:.2f}")
print("\nMean and Standard Deviation of Score for Middle East:")
print(f"Mean: {middle_east_mean:.2f}, Standard Deviation: {middle_east_std:.2f}")
# Out:
# Mean and Standard Deviation of Score for South Asia:
# Mean: 3.90, Standard Deviation: 1.18
#
# Mean and Standard Deviation of Score for Middle East:
# Mean: 5.41, Standard Deviation: 1.57

# %%
# Which region has higher happiness Scores on average?
if south_asia_mean > middle_east_mean:
    print("South Asia has higher happiness Scores on average.")
else:
    print("Middle East has higher happiness Scores on average.")
# Out:
# Middle East has higher happiness Scores on average.

# %% [markdown]
# 2. Top and Bottom Performers:
#
#   • Identify the top 3 and bottom 3 countries in each region based on the score.
#
#   • Plot bar charts comparing these charts.

# %%
# Identify the top 3 and bottom 3 countries in each region based on the score.
south_asia_top3=south_asia_data.sort_values(by='score', ascending=False).head(3)
print("Top 3 Countries in South Asia based on Score:\n")
print(south_asia_top3[['Country name','score']])
print("\nBottom 3 Countries in South Asia based on Score:\n")
south_asia_bottom3=south_asia_data.sort_values(by='score', ascending=True).head(3)
print(south_asia_bottom3[['Country name','score']])

middle_east_top3=middle_east_data.sort_values(by='score', ascending=False).head(3)
print("\nTop 3 Countries in Middle East based on Score:\n")
print(middle_east_top3[['Country name','score']])
print("\nBottom 3 Countries in MIddle East based on Score:\n")
middle_east_bottom3=middle_east_data.sort_values(by='score', ascending=True).head(3)
print(middle_east_bottom3[['Country name','score']])
# Out:
# Top 3 Countries in South Asia based on Score:
#
#   Country name  score
# 0        Nepal  5.158
# 1     Pakistan  4.657
# 2        India  4.054
#
# Bottom 3 Countries in South Asia based on Score:
#
#   Country name  score
# 5  Afghanistan  1.721
# 4   Bangladesh  3.886
# 3    Sri Lanka  3.898
#
# Top 3 Countries in Middle East based on Score:
#
#             Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733
#
# Bottom 3 Countries in MIddle East based on Score:
#
#     Country name  score
# 141      Lebanon  2.707
# 132        Yemen  3.561
# 124       Jordan  4.186

# %%
# Plot bar charts comparing these charts.
south_asia_performance = pd.concat([south_asia_top3, south_asia_bottom3])
middle_east_performance= pd.concat([middle_east_top3, middle_east_bottom3])

south_asia_performance['Performance'] = ['Top Countries']*3 + ['Bottom Countries']*3
middle_east_performance['Performance'] = ['Top Countries']*3 + ['Bottom Countries']*3

plt.figure(figsize=(10, 5))
sns.barplot(x='score', y='Country name', data=south_asia_performance, hue='Performance', dodge=False,
            palette={'Top Countries': 'green', 'Bottom Countries': 'red'})
plt.title('Top 3 and Bottom 3 Countries in South Asia',fontsize=16)
plt.xlabel('Happiness Score',fontsize=12)
plt.ylabel('Country',fontsize=12)
plt.legend(title='Performance')
plt.tight_layout()
plt.show()
print("\n")

plt.figure(figsize=(10, 5))
sns.barplot(x='score', y='Country name', data=middle_east_performance, hue='Performance', dodge=False,
            palette={'Top Countries': 'green', 'Bottom Countries': 'red'})
plt.title('Top 3 and Bottom 3 Countries in Middle East',fontsize=16)
plt.xlabel('Happiness Score',fontsize=12)
plt.ylabel('Country',fontsize=12)
plt.legend(title='Performance')
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
#
#   • Compare key metrics like GDP per Capita, Social Support,
#     and Healthy Life Expectancy between the regions using grouped bar charts.
#
#   • Which metrics show the largest disparity between the two regions?

# %%
# Compare key metrics like GDP per Capita, Social Support, and
# Healthy Life Expectancy between the regions using grouped bar charts.
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
south_asia_metrics = south_asia_data[metrics].mean()
middle_east_metrics = middle_east_data[metrics].mean()

comparison_data = pd.DataFrame({'South Asia': south_asia_metrics, 'Middle East': middle_east_metrics})
comparison_data.plot(kind='bar', figsize=(10, 5), color=['blue', 'orange'])
plt.title('Metric Comparison: South Asia vs Middle East',fontsize=16)
plt.ylabel('Mean Value',fontsize=12)
plt.xlabel('Metrics',fontsize=12)
plt.xticks(rotation=360)
plt.legend()
plt.show()

# %%
# Which metrics show the largest disparity between the two regions?
disparities = (middle_east_metrics- south_asia_metrics).abs()
print("The metric with the largest disparity is:", disparities.idxmax())
# Out:
# The metric with the largest disparity is: Social support

# %% [markdown]
# 4. Happiness Disparity:
#
#   • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
#   • Which region has greater variability in happiness?

# %%
# Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
south_asia_range = south_asia_data['score'].max() - south_asia_data['score'].min()
middle_east_range = middle_east_data['score'].max() - middle_east_data['score'].min()

south_asia_cv = south_asia_data['score'].std() / south_asia_data['score'].mean()
middle_east_cv = middle_east_data['score'].std() / middle_east_data['score'].mean()

print("Range (max - min) and Coefficient of Variation (CV) for Score in South Asia:")
print(f"Range: {south_asia_range:.2f}, Coefficient of Variation: {south_asia_cv:.2f}\n")
print("Range (max - min) and Coefficient of Variation (CV) for Score in Middle East:")
print(f"Range: {middle_east_range:.2f}, Coefficient of Variation: {middle_east_cv:.2f}")
# Out:
# Range (max - min) and Coefficient of Variation (CV) for Score in South Asia:
# Range: 3.44, Coefficient of Variation: 0.30
#
# Range (max - min) and Coefficient of Variation (CV) for Score in Middle East:
# Range: 4.63, Coefficient of Variation: 0.29

# %%
# Which region has greater variability in happiness?
if south_asia_cv > middle_east_cv:
    print("South Asia has greater variability in happiness scores.")
else:
    print("Middle East has greater variability in happiness scores.")
# Out:
# South Asia has greater variability in happiness scores.

# %% [markdown]
# 5. Correlation Analysis:
#
#   • Analyze the correlation of Score with other metrics Freedom to Make Life
#      Choices,and Generosity within each region.
#
#   • Create scatter plots to visualize and interpret the relationships.

# %%
# Analyze the correlation of Score with other metrics Freedom to Make Life Choices,and Generosity within each region.
analyzing_metrics = ['Freedom to make life choices', 'Generosity']
for metric in analyzing_metrics:
    south_asia_correlation = south_asia_data['score'].corr(south_asia_data[metric])
    middle_east_correlation = middle_east_data['score'].corr(middle_east_data[metric])
    print(f"Correlation of Score with {metric} in South Asia: {south_asia_correlation:.2f}")
    print(f"Correlation of Score with {metric} in Middle East: {middle_east_correlation:.2f}")
# Out:
# Correlation of Score with Freedom to make life choices in South Asia: 0.80
# Correlation of Score with Freedom to make life choices in Middle East: 0.86
# Correlation of Score with Generosity in South Asia: 0.87
# Correlation of Score with Generosity in Middle East: 0.63

# %%
# Create scatter plots to visualize and interpret the relationships.
for metric in analyzing_metrics:
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.regplot(x=metric, y='score', data=south_asia_data)
    plt.title(f'South Asia: {metric} vs Score',fontsize=16)
    plt.xlabel(metric)
    plt.ylabel('Score')

    plt.subplot(1, 2, 2)
    sns.regplot(x=metric, y='score', data=middle_east_data)
    plt.title(f'Middle East: {metric} vs Score',fontsize=16)
    plt.xlabel(metric)
    plt.ylabel('Score')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# 6. Outlier Detection:
#
#   • Identify outlier countries in both regions based on Score and GDP per Capita.
#
#   • Plot these outliers and discuss their implications.

# %%
# Identify outlier countries in both regions based on Score and GDP per Capita.
def detect_outliers(column, region_data):
    Q1 = region_data[column].quantile(0.25)
    Q3 = region_data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return region_data[(region_data[column] < lower_bound) | (region_data[column] > upper_bound)]

south_asia_outliers = detect_outliers('score', south_asia_data)
middle_east_outliers = detect_outliers('score', middle_east_data)

print("Outlier countries in Souch Asia:\n")
print(south_asia_outliers[['Country name']])
print("\nOutlier countries in Middle East:\n")
print(middle_east_outliers[['Country name']])
# Out:
# Outlier countries in Souch Asia:
#
#   Country name
# 5  Afghanistan
#
# Outlier countries in Middle East:
#
# Empty DataFrame
# Columns: [Country name]
# Index: []

# %%
# Plot these outliers and discuss their implications.
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_data, color='blue', label='South Asia')
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_data, color='orange', label='Middle East')
sns.scatterplot(x=south_asia_outliers['Log GDP per capita'], y=south_asia_outliers['score'], color='red', label='Outliers (South Asia)')
sns.scatterplot(x=middle_east_outliers['Log GDP per capita'], y=middle_east_outliers['score'], color='green', label='Outliers (Middle East)')
plt.title('Outliers Countries based on Score and GDP per Capita',fontsize=16)
plt.xlabel('GDP per Capita',fontsize=12)
plt.ylabel('Score',fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# 7. Visualization:
#
#    • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
#    • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# Create boxplots comparing the distribution of Score between South Asia and the Middle East.

score_comparison_data = pd.concat([south_asia_data[['score']].assign(Region='South Asia'),middle_east_data[['score']].assign(Region='Middle East')])
plt.figure(figsize=(8, 6))
sns.boxplot(data=score_comparison_data, x='Region', y='score', palette='Set2',hue='Region')

plt.title('Distribution of Score between South Asia and Middle East', fontsize=16)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
